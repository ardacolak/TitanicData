# %% [markdown]
# <a href="https://colab.research.google.com/github/ardacolak/TitanicData/blob/main/TitanicProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_test = pd.read_csv("train.csv")

# %%
df_test_kopya=df_test.copy()

# %%
df_test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_test.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_test.shape
# Out:
# (891, 12)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_test.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_test.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df_test.drop(columns=["PassengerId", "SibSp" , "Parch"], axis=1, inplace=False)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age            Ticket     Fare Cabin Embarked
# ...

# %%
df_test.Fare.unique()
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#         31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,  18.    ,
#          7.225 ,  26.    ,   8.0292,  35.5   ,  31.3875, 263.    ,
#          7.8792,   7.8958,  27.7208, 146.5208,   7.75  ,  10.5   ,
#         82.1708,  52.    ,   7.2292,  11.2417,   9.475 ,  21.    ,
#         41.5792,  15.5   ,  21.6792,  17.8   ,  39.6875,   7.8   ,
#         76.7292,  61.9792,  27.75  ,  46.9   ,  80.    ,  83.475 ,
#         27.9   ,  15.2458,   8.1583,   8.6625,  73.5   ,  14.4542,
#         56.4958,   7.65  ,  29.    ,  12.475 ,   9.    ,   9.5   ,
#          7.7875,  47.1   ,  15.85  ,  34.375 ,  61.175 ,  20.575 ,
#         34.6542,  63.3583,  23.    ,  77.2875,   8.6542,   7.775 ,
#         24.15  ,   9.825 ,  14.4583, 247.5208,   7.1417,  22.3583,
#          6.975 ,   7.05  ,  14.5   ,  15.0458,  26.2833,   9.2167,
# ...

# %%
df_test.Fare=round(df_test.Fare,0)
df_test.Fare.unique()
# Out:
# array([  7.,  71.,   8.,  53.,  52.,  21.,  11.,  30.,  17.,  27.,  31.,
#         16.,  29.,  13.,  18.,  26.,  36., 263.,  28., 147.,  10.,  82.,
#          9.,  42.,  22.,  40.,  77.,  62.,  47.,  80.,  83.,  15.,  74.,
#         14.,  56.,  12.,  34.,  61.,  35.,  63.,  23.,  24., 248.,  79.,
#         37.,  67.,  70.,  55.,  25.,   0.,  39.,  50.,   6.,  19., 113.,
#         76.,  90.,  20.,  86., 512., 153., 136.,  78.,  91., 152., 111.,
#        109.,  57., 262., 165., 134.,  58.,  75.,  69., 212.,   4., 228.,
#        120.,  32.,  89.,  38.,  59.,  94., 222., 106.,  51.,  33.,  65.,
#        211.,   5.])

# %%
df_test["Fare"].fillna(df_test["Fare"].mean(), inplace=True)
df_test.Fare=round(df_test.Fare,)
# Out:
# <ipython-input-62-e00d7d426fa8>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test["Fare"].fillna(df_test["Fare"].mean(), inplace=True)

# %%
average_fare = df_test['Fare'].mean()
print(f"Fare kolonunun ortalaması: {average_fare.round()}")
df_test.Fare.unique()
# Out:
# Fare kolonunun ortalaması: 32.0
# array([  7.,  71.,   8.,  53.,  52.,  21.,  11.,  30.,  17.,  27.,  31.,
#         16.,  29.,  13.,  18.,  26.,  36., 263.,  28., 147.,  10.,  82.,
#          9.,  42.,  22.,  40.,  77.,  62.,  47.,  80.,  83.,  15.,  74.,
#         14.,  56.,  12.,  34.,  61.,  35.,  63.,  23.,  24., 248.,  79.,
#         37.,  67.,  70.,  55.,  25.,   0.,  39.,  50.,   6.,  19., 113.,
#         76.,  90.,  20.,  86., 512., 153., 136.,  78.,  91., 152., 111.,
#        109.,  57., 262., 165., 134.,  58.,  75.,  69., 212.,   4., 228.,
#        120.,  32.,  89.,  38.,  59.,  94., 222., 106.,  51.,  33.,  65.,
#        211.,   5.])

# %%
plt.figure(figsize=(10, 6))
sns.stripplot(data=df_test, x='Pclass', y='Age', hue='Survived', jitter=True, dodge=True)
plt.title('Age ve Pclass')
plt.show()

# %% [markdown]
# 1. sınıf yolcularının çoğu hayatta kalırken, 3. sınıf yolcularının çoğu hayatını kaybetmiş.

# %%
plt.figure(figsize=(10, 6))
sns.stripplot(data=df_test, x='Pclass', y='Age', jitter=True, hue='Survived', dodge=True, palette='Set2')
plt.title('Sınıflara göre yas dagilimi')
plt.xlabel('Pclass')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# Her bir yolcu sınıfı için yaş dağılımını ve hayatta kalma durumlarını analiz ediyoruz.1.sınıf yolcularının yaşları genellikle  genç ya da yaşlı olabilirken, 3. sınıf yolcularının yaş dağılımı daha geniş bir aralığa sahip.

# %%
sns.countplot(x="Sex", hue="Survived", data=df_test)
plt.title("Cinsiyete Göre Hayatta Kalma")
plt.xlabel("Cinsiyet")
plt.ylabel("Kişi Sayısı")
plt.show()

# %% [markdown]
# Kadınlar için hayatta kalma oranı çok daha yüksekken, erkekler için bu oran oldukça düşük.Kaza sırasında erkeklerin eşlerini ve çocuklarını kurtarmak için kendilerini feda ettikleri düşünülebilir.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_test, x='Age', y='Fare', hue='Survived', palette='coolwarm')
plt.title('Age ve Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# Hayatta kalma oranı yüksek olan yolcular genellikle orta yaş gruplarından oluşurken, hayatta kalmayan yolcular daha çok yaşlı yolcular ve çocuklardan oluşuyor.

# %%
survival_sayac = df_test['Survived'].value_counts()
survival_labels = ['Hayatta Degil', 'Hayatta']

plt.figure(figsize=(8, 6))
plt.pie(survival_counts, labels=survival_labels, autopct='%1.1f%%', colors=['gray', 'cyan'])
plt.title('Hayatta kalma orani')
plt.show()

# %% [markdown]
# Gemideki çoğu insanin hayatini kaybettiği ve facianın ne kadar büyük olduğunu göstern bir grafik.
